# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from plot_func import error_scatter, interval_score, coverage, performance_dist, table

# Test Case 1 experimental data
# folder = "ipm_interp_temp"

folder = "synthetic_data/case11_1/pyvale-output/ipm_interp_temp"

metrics = ["total_plus", "total_minus"]
lrs = np.array([0.003, 0.01, 0.03, 0.1])
hidden_dims = np.array([1, 4, 16, 32, 64])

TOLERANCE=0.1

folder_plots = f"../../{folder}/plots/"

if not os.path.exists(folder_plots):
    os.makedirs(folder_plots)
    print(f"Directory '{folder_plots}' created.")
else:
    print(f"Directory '{folder_plots}' already exists.")
# Out:
# Directory '../../synthetic_data/case11_1/pyvale-output/ipm_interp_temp/plots/' created.

# %%
for hidden_dim in hidden_dims:
    for metric in metrics:

        model_type_prints = []
        for lr in lrs:
                    model_type_print = f"{lr}_{hidden_dim}"
                    model_type_prints.append(model_type_print)
        print(model_type_prints)


        dfs = []
    
        for lr in lrs:


                    model_type_print = f"{lr}_{hidden_dim}"
                    df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
                    df["model"] = model_type_print
                    dfs.append(df)

    
        df_all = pd.concat(dfs, ignore_index=True)
        
        fig, ax = error_scatter(df_all, TOLERANCE, tag=metric)
        save_path = f"../../{folder}/plots/error_scatter_{metric}_{model_type_print}.jpg"
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        plt.close(fig)

        fig, ax = interval_score(df_all, model_type_prints, tag=metric)
        save_path = f"../../{folder}/plots/interval_score_{metric}_{model_type_print}.jpg"
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        plt.close(fig)

        fig, ax = coverage(df_all, tag=metric)
        save_path = f"../../{folder}/plots/coverage_{metric}_{model_type_print}.jpg"
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        plt.close(fig)
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_1', '0.01_1', '0.03_1', '0.1_1']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_1', '0.01_1', '0.03_1', '0.1_1']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_4', '0.01_4', '0.03_4', '0.1_4']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_4', '0.01_4', '0.03_4', '0.1_4']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_16', '0.01_16', '0.03_16', '0.1_16']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_16', '0.01_16', '0.03_16', '0.1_16']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_32', '0.01_32', '0.03_32', '0.1_32']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_32', '0.01_32', '0.03_32', '0.1_32']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_64', '0.01_64', '0.03_64', '0.1_64']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_64', '0.01_64', '0.03_64', '0.1_64']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]

# %%
for hidden_dim in hidden_dims:
    for metric in metrics:

        model_type_prints = []
        for lr in lrs:
                    model_type_print = f"{lr}_{hidden_dim}"
                    model_type_prints.append(model_type_print)
        print(model_type_prints)

        for model_type_print in model_type_prints:
            df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
# Out:
# ['0.003_1', '0.01_1', '0.03_1', '0.1_1']
# ['0.003_1', '0.01_1', '0.03_1', '0.1_1']
# ['0.003_4', '0.01_4', '0.03_4', '0.1_4']
# ['0.003_4', '0.01_4', '0.03_4', '0.1_4']
# ['0.003_16', '0.01_16', '0.03_16', '0.1_16']
# ['0.003_16', '0.01_16', '0.03_16', '0.1_16']
# ['0.003_32', '0.01_32', '0.03_32', '0.1_32']
# ['0.003_32', '0.01_32', '0.03_32', '0.1_32']
# ['0.003_64', '0.01_64', '0.03_64', '0.1_64']
# ['0.003_64', '0.01_64', '0.03_64', '0.1_64']

# %%
all_results = []

for hidden_dim in hidden_dims:
    for metric in metrics:

        model_type_prints = []
        for lr in lrs:
                    model_type_print = f"{lr}_{hidden_dim}"
                    model_type_prints.append(model_type_print)
        print(model_type_prints)

        for model_type_print in model_type_prints:

            # filepath = (f"../../{folder}/ablation_results/"
            #             f"{metric}_ablation_{model_type_print}.csv"
            # )
            filepath = f"../../{folder}/ablation_summary_{model_type_print}.csv"

            df = pd.read_csv(filepath)

            # Store the model information with each result
            df["hidden_dim"] = hidden_dim
            df["metric"] = metric
            df["model_type"] = model_type_print

            all_results.append(df)


# Combine all summary files
results = pd.concat(all_results, ignore_index=True)
print(results)
# Out:
# ['0.003_1', '0.01_1', '0.03_1', '0.1_1']
# ['0.003_1', '0.01_1', '0.03_1', '0.1_1']
# ['0.003_4', '0.01_4', '0.03_4', '0.1_4']
# ['0.003_4', '0.01_4', '0.03_4', '0.1_4']
# ['0.003_16', '0.01_16', '0.03_16', '0.1_16']
# ['0.003_16', '0.01_16', '0.03_16', '0.1_16']
# ['0.003_32', '0.01_32', '0.03_32', '0.1_32']
# ['0.003_32', '0.01_32', '0.03_32', '0.1_32']
# ['0.003_64', '0.01_64', '0.03_64', '0.1_64']
# ['0.003_64', '0.01_64', '0.03_64', '0.1_64']
#                d_type        MAE       RMSE          MAPE  mean_abs_error  \
# 0            sim_plus  15.992678  18.689102  5.210156e+03       15.992678
# 1           sim_minus  14.340105  17.559746  6.041616e+03       14.340105
# 2     model_form_plus   2.263033   2.481968  3.727769e+06        2.263033
# 3    model_form_minus   2.730589   3.550865  4.641582e+01        2.730589
# 4          total_plus  11.994094  15.422001  1.807770e+02       11.994094
# ..                ...        ...        ...           ...             ...
# 235         sim_minus   7.486134  11.659218  1.540660e+03        7.486134
# 236   model_form_plus   1.272063   1.591234  1.298412e+05        1.272063
# 237  model_form_minus   1.537072   2.140196  2.206788e+01        1.537072
# 238        total_plus   8.770706  13.038389  8.846181e+01        8.770706
# 239       total_minus   6.246556   8.290728  6.520561e+01        6.246556
#
#      mean_rel_error  mean_pi_width  mean_pi_error  pi_coverage  \
# 0         52.101560      41.187444       0.106218     0.944444
# 1         60.416164      36.484357       0.100728     0.916667
# 2      37277.689502       5.480506       0.002404     0.833333
# 3          0.464158       7.339265       0.007185     0.916667
# 4          1.807770      31.945134       0.112057     0.944444
# ..              ...            ...            ...          ...
# 235       15.406597      19.482824       1.562652     0.750000
# 236     1298.412341       3.867696       0.030880     0.777778
# 237        0.220679       4.794774       0.172290     0.750000
# 238        0.884618      25.949779       0.986990     0.833333
# 239        0.652056      27.255419       0.150053     0.888889
#
#      mean_interval_score  accuracy_2pct  accuracy_2pct_matrix  TP  FP  TN  FN  \
# 0              45.436169       0.055556              0.055556   2  25   0   9
# 1              40.513496       0.138889              0.138889   3  22   2   9
# 2               5.576667       0.027778              0.027778   1  19   0  16
# 3               7.626680       0.416667              0.416667   5  17  10   4
# 4              36.427406       0.138889              0.138889   1  17   4  14
# ..                   ...            ...                   ...  ..  ..  ..  ..
# 235            81.988906       0.055556              0.055556   0  23   2  11
# 236             5.102877       0.194444              0.194444   5  19   2  10
# 237            11.686360       0.361111              0.361111   4  16   9   7
# 238            65.429375       0.138889              0.138889   3  18   2  13
# 239            33.257533       0.222222              0.222222   4  22   4   6
#
#      hidden_dim       metric model_type
# 0             1   total_plus    0.003_1
# 1             1   total_plus    0.003_1
# 2             1   total_plus    0.003_1
# 3             1   total_plus    0.003_1
# 4             1   total_plus    0.003_1
# ..          ...          ...        ...
# 235          64  total_minus     0.1_64
# 236          64  total_minus     0.1_64
# 237          64  total_minus     0.1_64
# 238          64  total_minus     0.1_64
# 239          64  total_minus     0.1_64
#
# [240 rows x 19 columns]

# %%
best_mean_rel_error = (
    results.loc[
        results.groupby("d_type")["mean_rel_error"].idxmin()
    ]
)

print(best_mean_rel_error[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_mean_rel_error[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_mean_rel_error.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type model_type  mean_rel_error  pi_coverage  \
# 195  model_form_minus   0.003_64        0.017355     0.888889
# 146   model_form_plus   0.003_32      743.374441     0.888889
# 193         sim_minus   0.003_64        1.444803     0.861111
# 192          sim_plus   0.003_64        1.620244     0.888889
# 149       total_minus   0.003_32        0.077558     0.888889
# 196        total_plus   0.003_64        0.128077     0.833333
#
#      mean_interval_score
# 195             0.765469
# 146             2.174419
# 193             4.528515
# 192             5.416365
# 149             4.657153
# 196             9.972766

# %%
best_interval_score = (
    results.loc[
        results.groupby("d_type")["mean_interval_score"].idxmin()
    ]
)

print(best_interval_score[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_interval_score[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_interval_score.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type model_type  mean_rel_error  pi_coverage  \
# 195  model_form_minus   0.003_64        0.017355     0.888889
# 194   model_form_plus   0.003_64     1172.740576     0.944444
# 145         sim_minus   0.003_32        1.982883     0.861111
# 144          sim_plus   0.003_32        1.683399     0.944444
# 149       total_minus   0.003_32        0.077558     0.888889
# 100        total_plus   0.003_16        0.138254     0.833333
#
#      mean_interval_score
# 195             0.765469
# 194             1.417236
# 145             4.029513
# 144             3.918145
# 149             4.657153
# 100             4.265652

# %%
target_coverage = 0.95

results["coverage_distance"] = (
    results["pi_coverage"] - target_coverage
).abs()

best_coverage = (
    results.loc[
        results.groupby("d_type")["coverage_distance"].idxmin()
    ]
)

print(best_coverage[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_coverage[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_coverage.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#               d_type model_type  mean_rel_error  pi_coverage  \
# 15  model_form_minus     0.03_1        0.547351     0.944444
# 8    model_form_plus     0.01_1    33325.297168     0.944444
# 1          sim_minus    0.003_1       60.416164     0.916667
# 0           sim_plus    0.003_1       52.101560     0.944444
# 5        total_minus    0.003_1        2.432798     0.944444
# 4         total_plus    0.003_1        1.807770     0.944444
#
#     mean_interval_score
# 15            10.166853
# 8              5.868423
# 1             40.513496
# 0             45.436169
# 5             51.090343
# 4             36.427406

# %%
results["rel_error_rank"] = (
    results.groupby("d_type")["mean_rel_error"]
    .rank(method="min", ascending=True)
)

results["interval_score_rank"] = (
    results.groupby("d_type")["mean_interval_score"]
    .rank(method="min", ascending=True)
)

results["coverage_rank"] = (
    results.groupby("d_type")["coverage_distance"]
    .rank(method="min", ascending=True)
)

results["overall_rank"] = (
    results["rel_error_rank"]
    + results["interval_score_rank"]
    + results["coverage_rank"]
)

# %%
best_overall = (
    results.loc[
        results.groupby("d_type")["overall_rank"].idxmin()
    ]
)

print(best_overall[
    [
        "d_type",
        "model_type",
        "mean_rel_error",
        "pi_coverage",
        "mean_interval_score",
        "overall_rank",
    ]
])


df_to_plot = best_overall[
    [
        "d_type",
        "model_type",
        "mean_rel_error",
        "pi_coverage",
        "mean_interval_score",
        "overall_rank",
    ]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_overall.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type model_type  mean_rel_error  pi_coverage  \
# 147  model_form_minus   0.003_32        0.030913     0.944444
# 194   model_form_plus   0.003_64     1172.740576     0.944444
# 145         sim_minus   0.003_32        1.982883     0.861111
# 144          sim_plus   0.003_32        1.683399     0.944444
# 197       total_minus   0.003_64        0.094566     0.916667
# 148        total_plus   0.003_32        0.147553     0.888889
#
#      mean_interval_score  overall_rank
# 147             0.797870           7.0
# 194             1.417236           5.0
# 145             4.029513          23.0
# 144             3.918145           5.0
# 197             5.877950          15.0
# 148             6.487654          21.0

# %%
# metrics_to_plot = {
#     "mean_rel_error": "Mean relative error",
#     "pi_coverage": "Prediction interval coverage",
#     "mean_interval_score": "Mean interval score",
# }

metrics_to_plot = {
    "mean_rel_error",
    "pi_coverage",
    "mean_interval_score",
}

for hidden_dim in results["hidden_dim"].unique():

    kernel_results = results[
        results["hidden_dim"] == hidden_dim
    ].copy()

    fig, axes = performance_dist(kernel_results, metrics_to_plot, hidden_dim)
    save_path = f"../../{folder}/plots/perform_dist_{hidden_dim}.jpg"
    fig.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.close(fig)
