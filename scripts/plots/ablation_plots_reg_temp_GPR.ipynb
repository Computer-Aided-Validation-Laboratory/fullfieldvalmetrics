# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from plot_func import error_scatter, interval_score, coverage, performance_dist, table

folder = "interp_gpr_temp"

metrics = ["total_plus", "total_minus"]
lrs = np.array([0.003, 0.01, 0.03, 0.1])
kernel_types = ["RBF", "Matern", "Linear"]
ard_num_dimss = np.array([None])
nus = np.array([2.5, 1.5])

TOLERANCE=0.1

# %%
for kernel_type in kernel_types:
    for metric in metrics:
        for nu in nus:

            model_type_prints = []
            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
                    else:
                        nu = None
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
            print(model_type_prints)
    
            dfs = []
        
            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        df_sum = pd.read_csv(f"../../{folder}/ablation_summary_{model_type_print}.csv")
                        # mean_rel_error = df_sum.loc[df_sum["d_type"] == metric, "mean_rel_error"].iloc[0]
                        df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
                        df["model"] = model_type_print
                        dfs.append(df)
                    else:
                        nu = None
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        df_sum = pd.read_csv(f"../../{folder}/ablation_summary_{model_type_print}.csv")
                        # mean_rel_error = df_sum.loc[df_sum["d_type"] == metric, "mean_rel_error"].iloc[0]
                        df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
                        df["model"] = model_type_print
                        dfs.append(df)

        
            df_all = pd.concat(dfs, ignore_index=True)
            
            fig, ax = error_scatter(df_all, TOLERANCE, tag=metric)
            save_path = f"../../{folder}/plots/error_scatter_{metric}_{model_type_print}.jpg"
            fig.savefig(save_path, dpi=300, bbox_inches="tight")
            plt.close(fig)

            fig, ax = interval_score(df_all, model_type_prints, tag=metric)
            save_path = f"../../{folder}/plots/interval_score_{metric}_{model_type_print}.jpg"
            fig.savefig(save_path, dpi=300, bbox_inches="tight")
            plt.close(fig)

            fig, ax = coverage(df_all, tag=metric)
            save_path = f"../../{folder}/plots/coverage_{metric}_{model_type_print}.jpg"
            fig.savefig(save_path, dpi=300, bbox_inches="tight")
            plt.close(fig)
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_2.5', '0.01_Matern_None_2.5', '0.03_Matern_None_2.5', '0.1_Matern_None_2.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_1.5', '0.01_Matern_None_1.5', '0.03_Matern_None_1.5', '0.1_Matern_None_1.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_2.5', '0.01_Matern_None_2.5', '0.03_Matern_None_2.5', '0.1_Matern_None_2.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_1.5', '0.01_Matern_None_1.5', '0.03_Matern_None_1.5', '0.1_Matern_None_1.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]

# %%
for kernel_type in kernel_types:
    for metric in metrics:
        for nu in nus:

            model_type_prints = []
            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
                    else:
                        nu = None
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
            print(model_type_prints)

            for model_type_print in model_type_prints:
                df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
# Out:
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# ['0.003_RBF_None_None', '0.01_RBF_None_None', '0.03_RBF_None_None', '0.1_RBF_None_None']
# ['0.003_Matern_None_2.5', '0.01_Matern_None_2.5', '0.03_Matern_None_2.5', '0.1_Matern_None_2.5']
# ['0.003_Matern_None_1.5', '0.01_Matern_None_1.5', '0.03_Matern_None_1.5', '0.1_Matern_None_1.5']
# ['0.003_Matern_None_2.5', '0.01_Matern_None_2.5', '0.03_Matern_None_2.5', '0.1_Matern_None_2.5']
# ['0.003_Matern_None_1.5', '0.01_Matern_None_1.5', '0.03_Matern_None_1.5', '0.1_Matern_None_1.5']
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']
# ['0.003_Linear_None_None', '0.01_Linear_None_None', '0.03_Linear_None_None', '0.1_Linear_None_None']

# %%
all_results = []

for kernel_type in kernel_types:
    for metric in metrics:
        for nu in nus:

            model_type_prints = []

            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                    else:
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_None"

                    model_type_prints.append(model_type_print)

            for model_type_print in model_type_prints:

                # filepath = (f"../../{folder}/ablation_results/"
                #             f"{metric}_ablation_{model_type_print}.csv"
                # )
                filepath = f"../../{folder}/ablation_summary_{model_type_print}.csv"

                df = pd.read_csv(filepath)

                # Store the model information with each result
                df["kernel_type"] = kernel_type
                df["metric"] = metric
                df["nu"] = nu if kernel_type == "Matern" else None
                df["model_type"] = model_type_print

                all_results.append(df)


# Combine all summary files
results = pd.concat(all_results, ignore_index=True)
print(results)
# Out:
#                d_type       MAE      RMSE           MAPE  mean_abs_error  \
# 0            sim_plus  0.380897  0.575429       1.586013        0.380897
# 1           sim_minus  0.235260  0.328775       1.109922        0.235260
# 2     model_form_plus  3.463069  4.956112    3992.795811        3.463069
# 3    model_form_minus  2.277027  3.196714  393703.484315        2.277027
# 4          total_plus  4.357206  5.739048      22.759414        4.357206
# ..                ...       ...       ...            ...             ...
# 283         sim_minus  0.145994  0.179305       1.403317        0.145994
# 284   model_form_plus  3.056496  4.145259    2493.161942        3.056496
# 285  model_form_minus  2.264645  3.189385  396612.419412        2.264645
# 286        total_plus  2.803369  4.123822      11.322253        2.803369
# 287       total_minus  2.446730  3.410680      22.524981        2.446730
#
#      mean_rel_error  mean_pi_width  mean_pi_error  pi_coverage  \
# 0          0.015860       1.000682       0.172323     0.571429
# 1          0.011099       0.757420       0.032295     0.571429
# 2         39.927958      10.098360       1.763464     0.714286
# 3       3937.034843       9.926377       1.108537     0.857143
# 4          0.227594      12.675417       1.834972     0.571429
# ..              ...            ...            ...          ...
# 283        0.014033       0.655441       0.015872     0.857143
# 284       24.931619      10.770582       1.192352     0.714286
# 285     3966.124194       9.942804       1.108531     0.857143
# 286        0.113223      11.015972       1.188712     0.714286
# 287        0.225250      11.558820       1.049310     0.857143
#
#      mean_interval_score  accuracy  accuracy_matrix  TP  FP  TN  FN  \
# 0               7.893616  1.000000         1.000000   3   0   4   0
# 1               2.049204  1.000000         1.000000   2   0   5   0
# 2              80.636917  0.000000         0.000000   0   6   0   1
# 3              54.267876  0.000000         0.000000   0   6   0   1
# 4              86.074294  0.428571         0.428571   0   3   3   1
# ..                   ...       ...              ...  ..  ..  ..  ..
# 283             1.290327  1.000000         1.000000   3   0   4   0
# 284            58.464660  0.000000         0.000000   0   6   0   1
# 285            54.284035  0.000000         0.000000   0   6   0   1
# 286            58.564464  0.571429         0.571429   2   2   2   1
# 287            53.531238  0.428571         0.428571   2   3   1   1
#
#     kernel_type       metric  nu            model_type
# 0           RBF   total_plus NaN   0.003_RBF_None_None
# 1           RBF   total_plus NaN   0.003_RBF_None_None
# 2           RBF   total_plus NaN   0.003_RBF_None_None
# 3           RBF   total_plus NaN   0.003_RBF_None_None
# 4           RBF   total_plus NaN   0.003_RBF_None_None
# ..          ...          ...  ..                   ...
# 283      Linear  total_minus NaN  0.1_Linear_None_None
# 284      Linear  total_minus NaN  0.1_Linear_None_None
# 285      Linear  total_minus NaN  0.1_Linear_None_None
# 286      Linear  total_minus NaN  0.1_Linear_None_None
# 287      Linear  total_minus NaN  0.1_Linear_None_None
#
# [288 rows x 20 columns]
# /tmp/ipykernel_772422/4175951526.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat(all_results, ignore_index=True)

# %%
best_mean_rel_error = (
    results.loc[
        results.groupby("d_type")["mean_rel_error"].idxmin()
    ]
)

print(best_mean_rel_error[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_mean_rel_error[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_mean_rel_error.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type              model_type  mean_rel_error  pi_coverage  \
# 195  model_form_minus  0.003_Linear_None_None     3850.646849     0.857143
# 206   model_form_plus   0.03_Linear_None_None       24.809636     0.714286
# 1           sim_minus     0.003_RBF_None_None        0.011099     0.571429
# 204          sim_plus   0.03_Linear_None_None        0.014081     1.000000
# 215       total_minus    0.1_Linear_None_None        0.225250     0.857143
# 208        total_plus   0.03_Linear_None_None        0.112914     0.714286
#
#      mean_interval_score
# 195            54.330369
# 206            58.203835
# 1               2.049204
# 204             0.789441
# 215            53.531238
# 208            58.950642

# %%
best_interval_score = (
    results.loc[
        results.groupby("d_type")["mean_interval_score"].idxmin()
    ]
)

print(best_interval_score[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_interval_score[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_interval_score.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type              model_type  mean_rel_error  pi_coverage  \
# 15   model_form_minus      0.03_RBF_None_None     3943.943345     0.857143
# 200   model_form_plus   0.01_Linear_None_None       25.114508     0.714286
# 97          sim_minus   0.003_Matern_None_2.5        0.013413     1.000000
# 210          sim_plus    0.1_Linear_None_None        0.014311     1.000000
# 209       total_minus   0.03_Linear_None_None        0.225952     0.857143
# 196        total_plus  0.003_Linear_None_None        0.112953     0.714286
#
#      mean_interval_score
# 15             54.243936
# 200            57.880632
# 97              0.879043
# 210             0.785495
# 209            53.491201
# 196            58.387729

# %%
target_coverage = 0.95

results["coverage_distance"] = (
    results["pi_coverage"] - target_coverage
).abs()

best_coverage = (
    results.loc[
        results.groupby("d_type")["coverage_distance"].idxmin()
    ]
)

print(best_coverage[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_coverage[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_coverage.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type             model_type  mean_rel_error  pi_coverage  \
# 3    model_form_minus    0.003_RBF_None_None     3937.034843     0.857143
# 2     model_form_plus    0.003_RBF_None_None       39.927958     0.714286
# 97          sim_minus  0.003_Matern_None_2.5        0.013413     1.000000
# 120          sim_plus  0.003_Matern_None_1.5        0.018346     1.000000
# 5         total_minus    0.003_RBF_None_None        0.333428     0.857143
# 124        total_plus  0.003_Matern_None_1.5        0.229872     0.714286
#
#      mean_interval_score
# 3              54.267876
# 2              80.636917
# 97              0.879043
# 120             1.690530
# 5              58.825782
# 124            74.052650

# %%
results["rel_error_rank"] = (
    results.groupby("d_type")["mean_rel_error"]
    .rank(method="min", ascending=True)
)

results["interval_score_rank"] = (
    results.groupby("d_type")["mean_interval_score"]
    .rank(method="min", ascending=True)
)

results["coverage_rank"] = (
    results.groupby("d_type")["coverage_distance"]
    .rank(method="min", ascending=True)
)

results["overall_rank"] = (
    results["rel_error_rank"]
    + results["interval_score_rank"]
    + results["coverage_rank"]
)

# %%
best_overall = (
    results.loc[
        results.groupby("d_type")["overall_rank"].idxmin()
    ]
)

print(best_overall[
    [
        "d_type",
        "model_type",
        "mean_rel_error",
        "pi_coverage",
        "mean_interval_score",
        "overall_rank",
    ]
])


df_to_plot = best_overall[
    [
        "d_type",
        "model_type",
        "mean_rel_error",
        "pi_coverage",
        "mean_interval_score",
        "overall_rank",
    ]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_overall.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type              model_type  mean_rel_error  pi_coverage  \
# 117  model_form_minus     0.1_Matern_None_2.5     3928.853958     0.857143
# 200   model_form_plus   0.01_Linear_None_None       25.114508     0.714286
# 97          sim_minus   0.003_Matern_None_2.5        0.013413     1.000000
# 204          sim_plus   0.03_Linear_None_None        0.014081     1.000000
# 203       total_minus   0.01_Linear_None_None        0.225942     0.857143
# 196        total_plus  0.003_Linear_None_None        0.112953     0.714286
#
#      mean_interval_score  overall_rank
# 117            54.264552          33.0
# 200            57.880632          11.0
# 97              0.879043          29.0
# 204             0.789441           7.0
# 203            53.508607          11.0
# 196            58.387729           7.0

# %%
# metrics_to_plot = {
#     "mean_rel_error": "Mean relative error",
#     "pi_coverage": "Prediction interval coverage",
#     "mean_interval_score": "Mean interval score",
# }

metrics_to_plot = {
    "mean_rel_error",
    "pi_coverage",
    "mean_interval_score",
}

for kernel_type in results["kernel_type"].unique():

    kernel_results = results[
        results["kernel_type"] == kernel_type
    ].copy()

    fig, axes = performance_dist(kernel_results, metrics_to_plot, kernel_type)
    save_path = f"../../{folder}/plots/perform_dist_{kernel_type}.jpg"
    fig.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.close(fig)
