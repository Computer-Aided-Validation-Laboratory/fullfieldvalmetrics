# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from plot_func import error_scatter, interval_score, coverage, performance_dist, table

folder = "interp_gpr_spatial"

metrics = ["total_plus", "total_minus"]
lrs = np.array([0.003, 0.01, 0.03, 0.1])
kernel_types = ["RBF", "Matern", "Linear"]
ard_num_dimss = np.array([None, 3])
nus = np.array([2.5, 1.5])

TOLERANCE=0.1

# %%
for kernel_type in kernel_types:
    for metric in metrics:
        for nu in nus:

            model_type_prints = []
            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
                    else:
                        nu = None
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
            print(model_type_prints)
    
            dfs = []
        
            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        df_sum = pd.read_csv(f"../../{folder}/ablation_summary_{model_type_print}.csv")
                        # mean_rel_error = df_sum.loc[df_sum["d_type"] == metric, "mean_rel_error"].iloc[0]
                        df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
                        df["model"] = model_type_print
                        dfs.append(df)
                    else:
                        nu = None
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        df_sum = pd.read_csv(f"../../{folder}/ablation_summary_{model_type_print}.csv")
                        # mean_rel_error = df_sum.loc[df_sum["d_type"] == metric, "mean_rel_error"].iloc[0]
                        df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
                        df["model"] = model_type_print
                        dfs.append(df)

        
            df_all = pd.concat(dfs, ignore_index=True)
            
            fig, ax = error_scatter(df_all, TOLERANCE, tag=metric)
            save_path = f"../../{folder}/plots/error_scatter_{metric}_{model_type_print}.jpg"
            fig.savefig(save_path, dpi=300, bbox_inches="tight")
            plt.close(fig)

            fig, ax = interval_score(df_all, model_type_prints, tag=metric)
            save_path = f"../../{folder}/plots/interval_score_{metric}_{model_type_print}.jpg"
            fig.savefig(save_path, dpi=300, bbox_inches="tight")
            plt.close(fig)

            fig, ax = coverage(df_all, tag=metric)
            save_path = f"../../{folder}/plots/coverage_{metric}_{model_type_print}.jpg"
            fig.savefig(save_path, dpi=300, bbox_inches="tight")
            plt.close(fig)
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_2.5', '0.003_Matern_3_2.5', '0.01_Matern_None_2.5', '0.01_Matern_3_2.5', '0.03_Matern_None_2.5', '0.03_Matern_3_2.5', '0.1_Matern_None_2.5', '0.1_Matern_3_2.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_1.5', '0.003_Matern_3_1.5', '0.01_Matern_None_1.5', '0.01_Matern_3_1.5', '0.03_Matern_None_1.5', '0.03_Matern_3_1.5', '0.1_Matern_None_1.5', '0.1_Matern_3_1.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_2.5', '0.003_Matern_3_2.5', '0.01_Matern_None_2.5', '0.01_Matern_3_2.5', '0.03_Matern_None_2.5', '0.03_Matern_3_2.5', '0.1_Matern_None_2.5', '0.1_Matern_3_2.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Matern_None_1.5', '0.003_Matern_3_1.5', '0.01_Matern_None_1.5', '0.01_Matern_3_1.5', '0.03_Matern_None_1.5', '0.03_Matern_3_1.5', '0.1_Matern_None_1.5', '0.1_Matern_3_1.5']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']
# /home/wiera/Documents/fullfieldvalmetrics/scripts/plots/plot_func.py:101: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_all.groupby("model")["within_pi"]

# %%
for kernel_type in kernel_types:
    for metric in metrics:
        for nu in nus:

            model_type_prints = []
            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
                    else:
                        nu = None
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                        model_type_prints.append(model_type_print)
            print(model_type_prints)

            for model_type_print in model_type_prints:
                df = pd.read_csv(f"../../{folder}/ablation_results/{metric}_ablation_{model_type_print}.csv")
# Out:
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# ['0.003_RBF_None_None', '0.003_RBF_3_None', '0.01_RBF_None_None', '0.01_RBF_3_None', '0.03_RBF_None_None', '0.03_RBF_3_None', '0.1_RBF_None_None', '0.1_RBF_3_None']
# ['0.003_Matern_None_2.5', '0.003_Matern_3_2.5', '0.01_Matern_None_2.5', '0.01_Matern_3_2.5', '0.03_Matern_None_2.5', '0.03_Matern_3_2.5', '0.1_Matern_None_2.5', '0.1_Matern_3_2.5']
# ['0.003_Matern_None_1.5', '0.003_Matern_3_1.5', '0.01_Matern_None_1.5', '0.01_Matern_3_1.5', '0.03_Matern_None_1.5', '0.03_Matern_3_1.5', '0.1_Matern_None_1.5', '0.1_Matern_3_1.5']
# ['0.003_Matern_None_2.5', '0.003_Matern_3_2.5', '0.01_Matern_None_2.5', '0.01_Matern_3_2.5', '0.03_Matern_None_2.5', '0.03_Matern_3_2.5', '0.1_Matern_None_2.5', '0.1_Matern_3_2.5']
# ['0.003_Matern_None_1.5', '0.003_Matern_3_1.5', '0.01_Matern_None_1.5', '0.01_Matern_3_1.5', '0.03_Matern_None_1.5', '0.03_Matern_3_1.5', '0.1_Matern_None_1.5', '0.1_Matern_3_1.5']
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']
# ['0.003_Linear_None_None', '0.003_Linear_3_None', '0.01_Linear_None_None', '0.01_Linear_3_None', '0.03_Linear_None_None', '0.03_Linear_3_None', '0.1_Linear_None_None', '0.1_Linear_3_None']

# %%
all_results = []

for kernel_type in kernel_types:
    for metric in metrics:
        for nu in nus:

            model_type_prints = []

            for lr in lrs:
                for ard_num_dims in ard_num_dimss:
                    if kernel_type == "Matern":
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_{nu}"
                    else:
                        model_type_print = f"{lr}_{kernel_type}_{ard_num_dims}_None"

                    model_type_prints.append(model_type_print)

            for model_type_print in model_type_prints:

                # filepath = (f"../../{folder}/ablation_results/"
                #             f"{metric}_ablation_{model_type_print}.csv"
                # )
                filepath = f"../../{folder}/ablation_summary_{model_type_print}.csv"

                df = pd.read_csv(filepath)

                # Store the model information with each result
                df["kernel_type"] = kernel_type
                df["metric"] = metric
                df["nu"] = nu if kernel_type == "Matern" else None
                df["model_type"] = model_type_print

                all_results.append(df)


# Combine all summary files
results = pd.concat(all_results, ignore_index=True)
print(results)
# Out:
#                d_type        MAE       RMSE           MAPE  mean_abs_error  \
# 0            sim_plus   4.400529   5.290095      30.309339        4.400529
# 1           sim_minus   4.354790   5.234667      31.613109        4.354790
# 2     model_form_plus   3.409630   4.669890    2082.159429        3.409630
# 3    model_form_minus   2.228331   3.173022  395014.935652        2.228331
# 4          total_plus  10.858952  11.728850      87.125593       10.858952
# ..                ...        ...        ...            ...             ...
# 571         sim_minus   2.526150   3.112265      26.694181        2.526150
# 572   model_form_plus   4.100259   5.611918    2748.823410        4.100259
# 573  model_form_minus   2.392573   3.255736  398332.576306        2.392573
# 574        total_plus   6.282975   7.597408      45.206344        6.282975
# 575       total_minus   3.544318   4.090579      32.446884        3.544318
#
#      mean_rel_error  mean_pi_width  mean_pi_error  pi_coverage  \
# 0          0.303093      16.316126       0.028188     0.857143
# 1          0.316131      16.123633       0.000000     1.000000
# 2         20.821594      10.339107       1.793373     0.714286
# 3       3950.149357       9.927009       1.108537     0.857143
# 4          0.871256      35.598255       1.849561     0.714286
# ..              ...            ...            ...          ...
# 571        0.266942       8.717001       0.539323     0.714286
# 572       27.488234       9.403111       2.387465     0.714286
# 573     3983.325763       9.938539       1.108537     0.857143
# 574        0.452063      16.841995       2.028616     0.714286
# 575        0.324469      13.727874       0.301527     0.714286
#
#      mean_interval_score  accuracy  accuracy_matrix  TP  FP  TN  FN  \
# 0              17.443629  0.285714         0.285714   2   2   0   3
# 1              16.123633  0.285714         0.285714   2   2   0   3
# 2              82.074046  0.000000         0.000000   0   6   0   1
# 3              54.268505  0.000000         0.000000   0   6   0   1
# 4             109.580689  0.000000         0.000000   0   5   0   2
# ..                   ...       ...              ...  ..  ..  ..  ..
# 571            30.289940  0.428571         0.428571   0   3   3   1
# 572           104.901693  0.000000         0.000000   0   6   0   1
# 573            54.280014  0.000000         0.000000   0   6   0   1
# 574            97.986646  0.142857         0.142857   1   4   0   2
# 575            25.788950  0.142857         0.142857   0   3   1   3
#
#     kernel_type       metric  nu           model_type
# 0           RBF   total_plus NaN  0.003_RBF_None_None
# 1           RBF   total_plus NaN  0.003_RBF_None_None
# 2           RBF   total_plus NaN  0.003_RBF_None_None
# 3           RBF   total_plus NaN  0.003_RBF_None_None
# 4           RBF   total_plus NaN  0.003_RBF_None_None
# ..          ...          ...  ..                  ...
# 571      Linear  total_minus NaN    0.1_Linear_3_None
# 572      Linear  total_minus NaN    0.1_Linear_3_None
# 573      Linear  total_minus NaN    0.1_Linear_3_None
# 574      Linear  total_minus NaN    0.1_Linear_3_None
# 575      Linear  total_minus NaN    0.1_Linear_3_None
#
# [576 rows x 20 columns]
# /tmp/ipykernel_760703/4175951526.py:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat(all_results, ignore_index=True)

# %%
best_mean_rel_error = (
    results.loc[
        results.groupby("d_type")["mean_rel_error"].idxmin()
    ]
)

print(best_mean_rel_error[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_mean_rel_error[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_mean_rel_error.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type             model_type  mean_rel_error  pi_coverage  \
# 261  model_form_minus      0.01_Matern_3_1.5     3731.733186     0.857143
# 242   model_form_plus  0.003_Matern_None_1.5       20.401297     0.714286
# 247         sim_minus     0.003_Matern_3_1.5        0.212436     0.714286
# 246          sim_plus     0.003_Matern_3_1.5        0.209727     0.714286
# 431       total_minus      0.1_Linear_3_None        0.324469     0.714286
# 424        total_plus   0.1_Linear_None_None        0.397584     0.714286
#
#      mean_interval_score
# 261            52.699962
# 242            79.385948
# 247            18.716365
# 246            19.169004
# 431            25.788950
# 424            99.753819

# %%
best_interval_score = (
    results.loc[
        results.groupby("d_type")["mean_interval_score"].idxmin()
    ]
)

print(best_interval_score[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_interval_score[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_interval_score.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type           model_type  mean_rel_error  pi_coverage  \
# 261  model_form_minus    0.01_Matern_3_1.5     3731.733186     0.857143
# 284   model_form_plus     0.1_Matern_3_1.5       49.699469     0.714286
# 37          sim_minus    0.1_RBF_None_None        0.306646     1.000000
# 0            sim_plus  0.003_RBF_None_None        0.303093     0.857143
# 431       total_minus    0.1_Linear_3_None        0.324469     0.714286
# 274        total_plus    0.03_Matern_3_1.5        0.399291     0.857143
#
#      mean_interval_score
# 261            52.699962
# 284            67.908512
# 37             15.485839
# 0              17.443629
# 431            25.788950
# 274            35.632185

# %%
target_coverage = 0.95

results["coverage_distance"] = (
    results["pi_coverage"] - target_coverage
).abs()

best_coverage = (
    results.loc[
        results.groupby("d_type")["coverage_distance"].idxmin()
    ]
)

print(best_coverage[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
])

df_to_plot = best_coverage[
    ["d_type", "model_type", "mean_rel_error", "pi_coverage", "mean_interval_score"]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_coverage.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type             model_type  mean_rel_error  pi_coverage  \
# 3    model_form_minus    0.003_RBF_None_None     3950.149357     0.857143
# 2     model_form_plus    0.003_RBF_None_None       20.821594     0.714286
# 1           sim_minus    0.003_RBF_None_None        0.316131     1.000000
# 192          sim_plus  0.003_Matern_None_2.5        0.385605     1.000000
# 197       total_minus  0.003_Matern_None_2.5        0.847316     0.857143
# 250        total_plus     0.003_Matern_3_1.5        0.730259     0.857143
#
#      mean_interval_score
# 3              54.268505
# 2              82.074046
# 1              16.123633
# 192            21.749320
# 197            41.874184
# 250            38.635409

# %%
results["rel_error_rank"] = (
    results.groupby("d_type")["mean_rel_error"]
    .rank(method="min", ascending=True)
)

results["interval_score_rank"] = (
    results.groupby("d_type")["mean_interval_score"]
    .rank(method="min", ascending=True)
)

results["coverage_rank"] = (
    results.groupby("d_type")["coverage_distance"]
    .rank(method="min", ascending=True)
)

results["overall_rank"] = (
    results["rel_error_rank"]
    + results["interval_score_rank"]
    + results["coverage_rank"]
)

# %%
best_overall = (
    results.loc[
        results.groupby("d_type")["overall_rank"].idxmin()
    ]
)

print(best_overall[
    [
        "d_type",
        "model_type",
        "mean_rel_error",
        "pi_coverage",
        "mean_interval_score",
        "overall_rank",
    ]
])


df_to_plot = best_overall[
    [
        "d_type",
        "model_type",
        "mean_rel_error",
        "pi_coverage",
        "mean_interval_score",
        "overall_rank",
    ]
]

fig, ax = table(df_to_plot)
save_path = f"../../{folder}/plots/best_overall.jpg"
fig.savefig(save_path, dpi=300, bbox_inches="tight")
plt.close(fig)
# Out:
#                d_type             model_type  mean_rel_error  pi_coverage  \
# 261  model_form_minus      0.01_Matern_3_1.5     3731.733186     0.857143
# 242   model_form_plus  0.003_Matern_None_1.5       20.401297     0.714286
# 37          sim_minus      0.1_RBF_None_None        0.306646     1.000000
# 246          sim_plus     0.003_Matern_3_1.5        0.209727     0.714286
# 431       total_minus      0.1_Linear_3_None        0.324469     0.714286
# 274        total_plus      0.03_Matern_3_1.5        0.399291     0.857143
#
#      mean_interval_score  overall_rank
# 261            52.699962           3.0
# 242            79.385948          11.0
# 37             15.485839          51.0
# 246            19.169004          67.0
# 431            25.788950          19.0
# 274            35.632185          11.0

# %%
# metrics_to_plot = {
#     "mean_rel_error": "Mean relative error",
#     "pi_coverage": "Prediction interval coverage",
#     "mean_interval_score": "Mean interval score",
# }

metrics_to_plot = {
    "mean_rel_error",
    "pi_coverage",
    "mean_interval_score",
}

for kernel_type in results["kernel_type"].unique():

    kernel_results = results[
        results["kernel_type"] == kernel_type
    ].copy()

    fig, axes = performance_dist(kernel_results, metrics_to_plot, kernel_type)
    save_path = f"../../{folder}/plots/perform_dist_{kernel_type}.jpg"
    fig.savefig(save_path, dpi=300, bbox_inches="tight")
    plt.close(fig)
